# %%
import numpy as np
import cv2 
import matplotlib.pyplot as plt

# %%
img_path = r'E:\Digital-image-ProcessingLab\assignment11\images\rose.jpg'
rgb = plt.imread(img_path)
plt.figure(figsize=(10,10))
plt.imshow(rgb)

# %%
grayscale_img = cv2.cvtColor(rgb,cv2.COLOR_RGB2GRAY)
plt.figure(figsize=(10,10))
plt.imshow(grayscale_img,cmap='gray')

# %%
# % perform fft on image
fftimg = np.fft.fft2(grayscale_img)
centered_fftimg = np.fft.fftshift(fftimg)
magnitude_spectram_fftimg = 100 * np.log(np.abs(fftimg))
magnitude_spectram_centered_fftimg = 100 * np.log(np.abs(centered_fftimg))

plt.figure(figsize=(10,10))
plt.imshow(magnitude_spectram_fftimg,cmap='gray')

plt.figure(figsize=(10,10))
plt.imshow(magnitude_spectram_centered_fftimg,cmap='gray')

# %%
filter1 = np.zeros(grayscale_img.shape)
filter1 = cv2.circle(filter1,(450,700),300,(255,255,255),-1)
plt.imshow(filter1,cmap='gray')

# %%
filter2 = np.zeros(grayscale_img.shape)
filter2 = cv2.circle(filter2,(450,700),300,(255,255,255),-1)
filter2 = cv2.circle(filter2,(450,700),400,(255,255,255),50)
plt.imshow(filter2,cmap='gray')

# %%
filter3 = np.zeros(grayscale_img.shape)
filter3 = cv2.rectangle(filter3,(300,400),(700,800),(255,255,255),-1)
plt.imshow(filter3,cmap='gray')

# %%
filter4 = np.zeros(grayscale_img.shape)
filter4 = cv2.rectangle(filter4,(300,400),(700,800),(255,255,255),-1)
filter4 = cv2.rectangle(filter4,(400,500),(600,700),(0,0,0),10)
plt.imshow(filter4,cmap='gray')
