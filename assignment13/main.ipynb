# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from PIL import Image

# %%
img_path = r'E:\Digital-image-ProcessingLab\assignment13\images\pp.jpg'
rgb = plt.imread(img_path)
plt.figure(figsize=(10,10))
plt.title("RGB image")
plt.imshow(rgb)

# %%
jpg_img = Image.open(img_path)
plt.imshow(jpg_img)
plt.title('JPEG to PNG')
jpg_img.save(r'E:\Digital-image-ProcessingLab\assignment13\images\jpg_to_png.png')

# %%
img2  = Image.open(r'E:\Digital-image-ProcessingLab\assignment13\images\jpg_to_png.png')
img2.save(r'E:\Digital-image-ProcessingLab\assignment13\images\png_to_jpg.jpg')
